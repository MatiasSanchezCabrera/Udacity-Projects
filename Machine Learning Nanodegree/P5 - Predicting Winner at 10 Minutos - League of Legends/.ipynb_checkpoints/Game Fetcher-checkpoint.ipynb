# %%
from riotwatcher import RiotWatcher
from riotwatcher import LoLException, error_500
import time
import os
import json
import pandas as pd
w = RiotWatcher('b6a1a049-887c-4b5e-bc1f-404b5a43e48d',default_region='LAS')

# %%
player = w.get_summoner('RBT Khynm1')

# %%
player = w.get_summoner('xMatías')

# %%
player_champion = pd.DataFrame([],columns=('player','lane','champ'))

# %%
print player['id']
print player['name']
# Out:
# 246615
# xMatías

# %%
matches = w.get_match_list(player['id'])

# %%
print matches
# Out:
# {u'matches': [{u'lane': u'JUNGLE', u'champion': 28, u'platformId': u'LA2', u'season': u'PRESEASON2017', u'region': u'LAS', u'matchId': 411405134, u'queue': u'TEAM_BUILDER_RANKED_SOLO', u'role': u'NONE', u'timestamp': 1483920001551L}, {u'lane': u'BOTTOM', u'champion': 412, u'platformId': u'LA2', u'season': u'PRESEASON2017', u'region': u'LAS', u'matchId': 410349187, u'queue': u'TEAM_BUILDER_RANKED_SOLO', u'role': u'DUO_SUPPORT', u'timestamp': 1483655461367L}, {u'lane': u'JUNGLE', u'champion': 28, u'platformId': u'LA2', u'season': u'PRESEASON2017', u'region': u'LAS', u'matchId': 409200541, u'queue': u'TEAM_BUILDER_RANKED_SOLO', u'role': u'NONE', u'timestamp': 1483367825328L}, {u'lane': u'JUNGLE', u'champion': 28, u'platformId': u'LA2', u'season': u'PRESEASON2017', u'region': u'LAS', u'matchId': 409159518, u'queue': u'TEAM_BUILDER_RANKED_SOLO', u'role': u'NONE', u'timestamp': 1483365676972L}, {u'lane': u'JUNGLE', u'champion': 28, u'platformId': u'LA2', u'season': u'PRESEASON2017', u'region': u'LAS', u'matchId': 408931368, u'queue': u'TEAM_BUILDER_RANKED_SOLO', u'role': u'NONE', u'timestamp': 1483300806887L}, {u'lane': u'MID', u'champion': 161, u'platformId': u'LA2', u'season': u'PRESEASON2017', u'region': u'LAS', u'matchId': 408568942, u'queue': u'TEAM_BUILDER_RANKED_SOLO', u'role': u'SOLO', u'timestamp': 1483195278432L}, {u'lane': u'MID', u'champion': 99, u'platformId': u'LA2', u'season': u'PRESEASON2017', u'region': u'LAS', u'matchId': 408578283, u'queue': u'TEAM_BUILDER_RANKED_SOLO', u'role': u'SOLO', u'timestamp': 1483193893424L}, {u'lane': u'JUNGLE', u'champion': 28, u'platformId': u'LA2', u'season': u'PRESEASON2017', u'region': u'LAS', u'matchId': 408287988, u'queue': u'TEAM_BUILDER_RANKED_SOLO', u'role': u'NONE', u'timestamp': 1483124913885L}, {u'lane': u'MID', u'champion': 99, u'platformId': u'LA2', u'season': u'PRESEASON2017', u'region': u'LAS', u'matchId': 408295660, u'queue': u'TEAM_BUILDER_RANKED_SOLO', u'role': u'SOLO', u'timestamp': 1483121725004L}, {u'lane': u'JUNGLE', u'champion': 28, u'platformId': u'LA2', u'season': u'PRESEASON2017', u'region': u'LAS', u'matchId': 406604479, u'queue': u'TEAM_BUILDER_RANKED_SOLO', u'role': u'NONE', u'timestamp': 1482705707214L}, {u'lane': u'MID', u'champion': 99, u'platformId': u'LA2', u'season': u'PRESEASON2017', u'region': u'LAS', u'matchId': 405887557, u'queue': u'TEAM_BUILDER_RANKED_SOLO', u'role': u'SOLO', u'timestamp': 1482527005729L}, {u'lane': u'TOP', u'champion': 28, u'platformId': u'LA2', u'season': u'PRESEASON2017', u'region': u'LAS', u'matchId': 405886599, u'queue': u'TEAM_BUILDER_RANKED_SOLO', u'role': u'DUO', u'timestamp': 1482525519502L}, {u'lane': u'JUNGLE', u'champion': 28, u'platformId': u'LA2', u'season': u'PRESEASON2017', u'region': u'LAS', u'matchId': 405818083, u'queue': u'TEAM_BUILDER_RANKED_SOLO', u'role': u'NONE', u'timestamp': 1482510290611L}, {u'lane': u'MID', u'champion': 99, u'platformId': u'LA2', u'season': u'PRESEASON2017', u'region': u'LAS', u'matchId': 405456396, u'queue': u'TEAM_BUILDER_RANKED_SOLO', u'role': u'SOLO', u'timestamp': 1482415949396L}, {u'lane': u'BOTTOM', u'champion': 412, u'platformId': u'LA2', u'season': u'PRESEASON2017', u'region': u'LAS', u'matchId': 405241327, u'queue': u'TEAM_BUILDER_RANKED_SOLO', u'role': u'DUO_SUPPORT', u'timestamp': 1482356410690L}, {u'lane': u'JUNGLE', u'champion': 28, u'platformId': u'LA2', u'season': u'PRESEASON2017', u'region': u'LAS', u'matchId': 404250879, u'queue': u'TEAM_BUILDER_RANKED_SOLO', u'role': u'NONE', u'timestamp': 1482109633586L}, {u'lane': u'JUNGLE', u'champion': 28, u'platformId': u'LA2', u'season': u'PRESEASON2017', u'region': u'LAS', u'matchId': 403810183, u'queue': u'TEAM_BUILDER_RANKED_SOLO', u'role': u'NONE', u'timestamp': 1482003553339L}, {u'lane': u'JUNGLE', u'champion': 121, u'platformId': u'LA2', u'season': u'PRESEASON2017', u'region': u'LAS', u'matchId': 403505682, u'queue': u'TEAM_BUILDER_RANKED_SOLO', u'role': u'NONE', u'timestamp': 1481937282970L}, {u'lane': u'MID', u'champio ...

# %%
for match in matches['matches']:
    if match['season']=='PRESEASON2017' and match['queue']=='TEAM_BUILDER_RANKED_SOLO':
        print match['lane'] + " as " + w.static_get_champion(match['champion'])['key']
        player_champion = player_champion.append(pd.DataFrame([[player['name'],match['lane'],w.static_get_champion(match['champion'])['key']]],columns=('player','lane','champ')))
# Out:
# JUNGLE as Evelynn
# BOTTOM as Thresh
# JUNGLE as Evelynn
# JUNGLE as Evelynn
# JUNGLE as Evelynn
# MID as Velkoz
# MID as Lux
# JUNGLE as Evelynn
# MID as Lux
# JUNGLE as Evelynn
# MID as Lux
# TOP as Evelynn
# JUNGLE as Evelynn
# MID as Lux
# BOTTOM as Thresh
# JUNGLE as Evelynn
# JUNGLE as Evelynn
# JUNGLE as Khazix
# MID as Lux
# JUNGLE as Evelynn
# MID as Lux
# JUNGLE as Khazix
# MID as Lux
# MID as Lux
# BOTTOM as Jinx
# JUNGLE as Khazix
# MID as Lux
# MID as Lux
# MID as Lux
# BOTTOM as Leona
# MID as Lux
# MID as Lux

# %%
print player_champion
# Out:
#     player    lane    champ
# 0  xMatías  JUNGLE  Evelynn
# 0  xMatías  BOTTOM   Thresh
# 0  xMatías  JUNGLE  Evelynn
# 0  xMatías  JUNGLE  Evelynn
# 0  xMatías  JUNGLE  Evelynn
# 0  xMatías     MID   Velkoz
# 0  xMatías     MID      Lux
# 0  xMatías  JUNGLE  Evelynn
# 0  xMatías     MID      Lux
# 0  xMatías  JUNGLE  Evelynn
# 0  xMatías     MID      Lux
# 0  xMatías     TOP  Evelynn
# 0  xMatías  JUNGLE  Evelynn
# 0  xMatías     MID      Lux
# 0  xMatías  BOTTOM   Thresh
# 0  xMatías  JUNGLE  Evelynn
# 0  xMatías  JUNGLE  Evelynn
# 0  xMatías  JUNGLE   Khazix
# 0  xMatías     MID      Lux
# 0  xMatías  JUNGLE  Evelynn
# 0  xMatías     MID      Lux
# 0  xMatías  JUNGLE   Khazix
# 0  xMatías     MID      Lux
# 0  xMatías     MID      Lux
# 0  xMatías  BOTTOM     Jinx
# 0  xMatías  JUNGLE   Khazix
# 0  xMatías     MID      Lux
# 0  xMatías     MID      Lux
# 0  xMatías     MID      Lux
# 0  xMatías  BOTTOM    Leona
# 0  xMatías     MID      Lux
# 0  xMatías     MID      Lux

# %%
# Check if game was already fetched
def check_file_exists(path):
    try:
        text_file = open(path,'r')
        # print 'Repeated Game'
        text_file.close()
        return False
    except IOError:
        return True

# %%
# Search for ranked matches based on seed players
def search_games(seed_players, checked_players):
    fellow_players = []
    for player in seed_players:
        if player not in checked_players:
            # Get recent games.
            # print 'Checking Player %s' % str(player)
            try:
                time.sleep(1.2)
                recent_games = w.get_recent_games(player)
                for game in recent_games['games']:
                    # Check if game is ranked
                    if game['subType'] == 'RANKED_SOLO_5x5' or game['subType'] == 'RANKED_PREMADE_5x5':
                        path = str(os.getcwd()) + "/Games/" + str(game['gameId']) + ".json"
                        # Check if game was saved before
                        if check_file_exists(path):
                            time.sleep(1.2)
                            # Get game data and save json
                            try:
                                game_data = w.get_match(game['gameId'], include_timeline=True) 
                                with open(path, "w") as text_file:
                                    json.dump(game_data,text_file)
                                text_file.close() 
                            except LoLException as error:
                                if error == error_500:
                                    print 'Error 500'
                    # Get fellow players
                    try:
                        for player in game['fellowPlayers']:
                            fellow_players.append(player['summonerId'])
                    except KeyError:
                        print 'No fellow Players'
            except LoLException as error:
                if error == error_500:
                    print 'Error 500'
        else:
            print 'Repeated Player'
    return fellow_players

# %%
seed_players = []
searched_players = []
seed_players.append(w.get_summoner(name='flsqm')['id'])
seed_players.append(w.get_summoner(name='jiezou11')['id'])
seed_players.append(w.get_summoner(name='Ssvage')['id'])
seed_players.append(w.get_summoner(name='whitebone45')['id'])
seed_players.append(w.get_summoner(name='Cafez')['id'])
time.sleep(12)
fellow_players = search_games(seed_players, searched_players)
searched_players = searched_players + seed_players
fellow_players2 = search_games(fellow_players,searched_players)
searched_players = searched_players + fellow_players
fellow_players3 = search_games(fellow_players2,searched_players)
searched_players = searched_players + fellow_players2
fellow_players4 = search_games(fellow_players3,searched_players)
searched_players = searched_players + fellow_players3
# Out:
# ---------------------------------------------------------------------------
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-5-3525d92a5a1c> in <module>()
#       1 seed_players = []
#       2 searched_players = []
# ----> 3 seed_players.append(w.get_summoner(name='flsqm')['id'])
#       4 seed_players.append(w.get_summoner(name='jiezou11')['id'])
#       5 seed_players.append(w.get_summoner(name='Ssvage')['id'])
#
# c:\users\matias\miniconda3\envs\riotapi\lib\site-packages\riotwatcher\riotwatcher.pyc in get_summoner(self, name, _id, region)
#     598             if name is not None:
#     599                 name = self.sanitized_name(name)
# --> 600                 key, summoner = self.get_summoners(names=[name, ], region=region).popitem()
#     601                 return summoner
#     602             else:
#
# c:\users\matias\miniconda3\envs\riotapi\lib\site-packages\riotwatcher\riotwatcher.pyc in get_summoners(self, names, ids, region)
#     589                     summoner_names=','.join([self.sanitized_name(n) for n in names])) if names is not None
#     590                 else '{summoner_ids}'.format(summoner_ids=','.join([str(i) for i in ids])),
# --> 591                 region
#     592             )
#     593         else:
#
# c:\users\matias\miniconda3\envs\riotapi\lib\site-packages\riotwatcher\riotwatcher.pyc in _summoner_request(self, end_url, region, **kwargs)
#     568             ),
#     569             region,
# --> 570             **kwargs
#     571         )
#     572
#
# c:\users\matias\miniconda3\envs\riotapi\lib\site-packages\riotwatcher\riotwatcher.pyc in base_request(self, url, region, static, **kwargs)
#     259                 url=url
#     260             ),
# --> 261             params=args
#     262         )
#     263         if not static:
#
# c:\users\matias\miniconda3\envs\riotapi\lib\site-packages\requests\api.pyc in get(url, params, **kwargs)
#      68
#      69     kwargs.setdefault('allow_redirects', True)
# ---> 70     return request('get', url, params=params, **kwargs)
#      71
#      72
#
# c:\users\matias\miniconda3\envs\riotapi\lib\site-packages\requests\api.pyc in request(method, url, **kwargs)
#      54     # cases, and look like a memory leak in others.
#      55     with sessions.Session() as session:
# ---> 56         return session.request(method=method, url=url, **kwargs)
#      57
#      58
#
# c:\users\matias\miniconda3\envs\riotapi\lib\site-packages\requests\sessions.pyc in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     486         }
#     487         send_kwargs.update(settings)
# --> 488         resp = self.send(prep, **send_kwargs)
#     489
#     490         return resp
#
# c:\users\matias\miniconda3\envs\riotapi\lib\site-packages\requests\sessions.pyc in send(self, request, **kwargs)
#     607
#     608         # Send the request
# --> 609         r = adapter.send(request, **kwargs)
#     610
#     611         # Total elapsed time of the request (approximately)
#
# c:\users\matias\miniconda3\envs\riotapi\lib\site-packages\requests\adapters.pyc in send(self, request, stream, timeout, verify, cert, proxies)
#     485                 raise ProxyError(e, request=request)
#     486
# --> 487             raise ConnectionError(e, request=request)
#     488
#     489         except ClosedPoolError as e:
#
# ConnectionError: HTTPSConnectionPool(host='natr.api.pvp.net', port=443): Max retries exceeded with url: /api/lol/NATR/v1.4/summoner/by-name/flsqm?api_key=b6a1a049-887c-4b5e-bc1f-404b5a43e48d (Caused by NewConnectionError('<requests.packages.urllib3.connection.VerifiedHTTPSConnection object at 0x0000000005E9BEF0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed',))
